# %% [markdown]
# # Machine Learning Classification

# %% [markdown]
# ### Explore how different machine learning models predict flower species based on physical measurements of the iris flowers.

# %% [markdown]
# #### You can experiment with different input features and observe how changes affect prediction accuracy and model performance.

# %% [markdown]
# ### Learning Objectives
# - After completing this lab, you will be able to:
# - Explore and interact with a classification model in real-time
# - Modify input features and observe how these changes affect prediction accuracy
# - Interpret key classification metrics such as accuracy, confusion matrix, and classification report
# - Experiment with different feature combinations and understand their impact on model performance

# %% [markdown]
# ### Data Dictionary
# - Column	Description
# - sepal length (cm)	Length of the sepal
# - sepal width (cm)	Width of the sepal
# - petal length (cm)	Length of the petal
# - petal width (cm)	Width of the petal
# - target	Species type (0 = Setosa, 1 = Versicolor, 2 = Virginica)
# ### Features used for prediction:
# - sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)
# ### Target:
# - species of the iris flower (encoded as 0, 1, or 2)
# #### A classification model is trained to predict the flower species.

# %% [markdown]
# pip install dash pandas plotly scikit-learn numpy

# %% [raw]
# Successfully installed Flask-3.1.3 Werkzeug-3.1.7 blinker-1.9.0 certifi-2026.2.25 charset_normalizer-3.4.6 click-8.3.1 dash-4.1.0 idna-3.11 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.3 markupsafe-3.0.3 narwhals-2.18.1 nest-asyncio-1.6.0 numpy-2.2.6 packaging-26.0 pandas-2.3.3 plotly-6.6.0 python-dateutil-2.9.0.post0 pytz-2026.1.post1 requests-2.33.0 retrying-1.4.2 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0 typing_extensions-4.15.0 tzdata-2025.3 urllib3-2.6.3

# %%
classificationapp.py

# %%
import dash
from dash import dcc, html, Input, Output
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)
import numpy as np

# Load Iris dataset
iris = load_iris(as_frame=True)
df = iris.frame
target_names = iris.target_names

# Create Dash app
app = dash.Dash(__name__)

# App layout
app.layout = html.Div([
    html.H1("🌼 Iris Species Classifier", style={'textAlign': 'center'}),

    html.Label("🌿 Choose input features:"),
    dcc.Dropdown(
        id='feature-selector',
        options=[{'label': col, 'value': col} for col in iris.feature_names],
        value=['sepal length (cm)', 'petal length (cm)'],
        multi=True
    ),

    dcc.Graph(id='classification-graph'),
    html.Div(id='accuracy', style={'fontSize': 20, 'marginTop': '20px'}),

    html.H3("🔍 Confusion Matrix"),
    dcc.Graph(id='confusion-matrix'),

    html.H3("📊 Classification Report (F1, Precision, Recall)"),
    html.Pre(id='report', style={'whiteSpace': 'pre-wrap', 'fontSize': 16})
])

@app.callback(
    Output('classification-graph', 'figure'),
    Output('accuracy', 'children'),
    Output('confusion-matrix', 'figure'),
    Output('report', 'children'),
    Input('feature-selector', 'value')
)
def update_classification(features):
    if len(features) < 1:
        return {}, "⚠️ Please select at least one feature.", {}, ""

    X = df[features]
    y = df['target']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    model = RandomForestClassifier(n_estimators=50, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    labels = list(target_names)

    # Main classification chart
    if len(features) == 2:
        fig = px.scatter(
            X_test,
            x=features[0],
            y=features[1],
            color=[target_names[i] for i in y_pred],
            title="🌸 Predicted Classes (Test Set)"
        )
    else:
        fig = px.histogram(x=[target_names[i] for i in y_pred], title="🌸 Predicted Class Distribution")

    # Confusion Matrix Plot
    cm = confusion_matrix(y_test, y_pred)
    cm_fig = ff.create_annotated_heatmap(
        z=cm,
        x=labels,
        y=labels,
        colorscale='Blues',
        showscale=True
    )
    cm_fig.update_layout(
        title="Confusion Matrix",
        xaxis_title="Predicted",
        yaxis_title="Actual"
    )

    # Classification Report (per-class F1 etc.)
    report_text = classification_report(y_test, y_pred, target_names=labels)

    return fig, f"✅ Accuracy: {acc:.2%}", cm_fig, report_text

if __name__ == '__main__':
    app.run()

# %% [markdown]
# 2. Open Your Project in VS Code
# Open VS Code
# Click File → Open Folder
# Select the folder where your .py file is saved

# %%
python classificationapp.py

# %%
C:\Users\HRIDYA\Desktop\AI ML\Coursera\IBM\Machine Learning\IRIS CLASSIFICATION PROJECT>python classificationapp.py
Dash is running on http://127.0.0.1:8050/

 * Serving Flask app 'classificationapp'
 * Debug mode: off
WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
 * Running on http://127.0.0.1:8050
Press CTRL+C to quit

# %%
http://127.0.0.1:8050

# %% [raw]
# Select sepal length from the feature dropdown.
# Image207.png
#
# Image210.png
#
# Interpretation
# Predicted Class Distribution
# The dataset contains a total of 30 data points, with the following observations:
#
# 11 were predicted to belong to the Versicolor flower species.
# 8 were predicted to belong to the Virginica flower species.
# 11 were predicted to belong to the Setosa flower species.
# Accuracy
# The accuracy is about 66.67%.
#
# Confusion Matrix
# True Positives (correct predictions on the diagonal):
# Setosa predicted as Setosa: 10
# Versicolor predicted as Versicolor: 7
# Virginica predicted as Virginica: 3
# Misclassifications (off-diagonal values):
# 1 Versicolor was wrongly predicted as Setosa
# 5 Versicolor were wrongly predicted as Virginica
# 1 Setosa was wrongly predicted as Versicolor
# 3 Virginica were predicted as Versicolor
# 0 Virginica were predicted as Setosa
# Inferences
# The model performs very well for Setosa, moderately for Virginica, and poorly for Versicolor.
#
# Class imbalance or overlapping features may be causing confusion, especially between Versicolor and Virginica.

# %% [raw]
# Interpretation
# Image211.pngImage212.png
#
# Predicted Class Distribution
# The dataset contains a total of 30 data points, with the following observations:
#
# 13 were predicted to belong to the Versicolor flower species.
# 5 were predicted to belong to the Virginica flower species.
# 11 were predicted to belong to the Setosa flower species.
# Accuracy
# The accuracy is 96.67%, which means the model predicted the correct species for 29 out of 30 samples.
#
# Confusion Matrix
# True Positives (correct predictions on the diagonal):
#
# Setosa predicted as Setosa: 11
# Versicolor predicted as Versicolor: 13
# Virginica predicted as Virginica: 5
# Misclassifications (off-diagonal values):
#
# 1 Virginica was wrongly predicted as Versicolor

# %% [raw]
# Conclusion
# In this lab, you successfully explored the interactive classification application using the Iris dataset. By modifying input features, you were able to observe how changes in the data affect model predictions and accuracy. This process demonstrated the fundamentals of machine learning classification, including interpreting key metrics such as accuracy, confusion matrix, and classification reports. You can now apply these techniques to experiment with different features and improve classification models in various real-world scenarios.
